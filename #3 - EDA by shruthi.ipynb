# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from datetime import datetime, timedelta


df= pd.read_csv('processed_data.csv')

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      252288          3       0         3990     -1      825          662
# 2      210048          3       1         4255     -1      866         1213
# 3      210048          3       1         4255     -1      866         1213
# 4      210048          3       1         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015          4       0         4255     -1      866         1213
# 4640   230015          4       0         4255     -1      866         1213
# 4641    64895          3       0         3491     -1      860         1238
# 4642     5759          6       0         4255     -1      866         1213
# 4643    96383          4       1         3462     -1      916          563
#
#       brand_id  time_stamp  action_type
# 0         7334        1017            0
# 1         5644         819            0
# 2         1573         711            2
# 3         1573         711            0
# 4         1573         711            0
# ...        ...         ...          ...
# 4639      1573         710            2
# 4640      1573         710            0
# 4641      3969         529            0
# 4642      1573         815            2
# 4643      2997         904            0
#
# [4644 rows x 10 columns]

# %%
gender_labels = {0: 'Female', 1: 'Male', 2: 'Unknown'}
df['gender_label'] = df['gender'].replace(gender_labels)

sns.countplot(x='age_range', hue='gender_label', data=df, palette='Set2')
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='count'>

# %% [markdown]
# ## Identifying the categories that have the highest spending by female customers.

# %% [markdown]
# Set of Catgegories in the given dataset :

# %%
distinct_categories = df['category_id'].unique()
distinct_categories
# Out:
# array([ 656,  662, 1213, 1112, 1389,  308, 1467,  276,  120,  898, 1591,
#         302,  834, 1098, 1075,  407, 1528,  737,  267, 1397, 1147,  420,
#         500,  639,  389,  563,  266,  351, 1181, 1238,  833, 1438, 1505,
#        1023,  177, 1188,  555,  180,  614, 1401, 1656, 1095,   36,   35,
#         464, 1553,  748, 1157,  278, 1228,  154, 1577,  946,  384,  844,
#        1431,    2, 1142,  766,  812, 1486, 1611,  451, 1124,  756, 1326,
#          11, 1293, 1657,  387,  815,  163,  895, 1271,  602,  641,  992,
#         795, 1174, 1208,  184,   73,  628, 1518,  247,  825])

# %%
female_df = df[df['gender'] == 0]

grouped_female_customers = female_df.groupby('category_id')

# Iterate over each group and print the results
for category_id, group in grouped_female_customers:
    print('Category ID:', category_id)
    print(group.age_range,"\n")
# Out:
# Category ID: 2
# 890    6
# Name: age_range, dtype: int64
#
# Category ID: 11
# 1284    0
# 1679    7
# 2734    4
# 2815    4
# 2816    4
# 2837    4
# 3286    4
# 3846    3
# 3880    3
# 4279    0
# 4281    4
# Name: age_range, dtype: int64
#
# Category ID: 35
# 620     5
# 2618    4
# 2731    0
# Name: age_range, dtype: int64
#
# Category ID: 36
# 611     4
# 612     4
# 1367    2
# 1549    3
# 3578    6
# Name: age_range, dtype: int64
#
# Category ID: 73
# 3319    3
# 3320    3
# Name: age_range, dtype: int64
#
# Category ID: 120
# 57      3
# 384     5
# 1504    3
# 4289    0
# 4562    3
# Name: age_range, dtype: int64
#
# Category ID: 154
# 761    2
# Name: age_range, dtype: int64
#
# Category ID: 177
# 340     4
# 767     4
# 3791    5
# 4431    6
# 4432    6
# 4433    6
# 4434    6
# 4548    2
# Name: age_range, dtype: int64
#
# Category ID: 180
# 377     4
# 1119    0
# 3413    4
# 4426    4
# 4429    3
# Name: age_range, dtype: int64
#
# Category ID: 184
# 3093    6
# Name: age_range, dtype: int64
#
# Category ID: 266
# 173     6
# 385     4
# 4522    5
# Name: age_range, dtype: int64
#
# Category ID: 267
# 226     4
# 1514    5
# 1515    5
# 1561    3
# 2047    4
# 2622    0
# 2646    4
# 3488    3
# 3641    2
# Name: age_range, dtype: int64
#
# Category ID: 276
# 2034    5
# 2370    3
# 2767    2
# 2768    2
# 2866    3
# 2867    3
# 2868    3
# 2900    4
# 2914    3
# 4240    5
# 4546    6
# Name: age_range, dtype: int64
#
# Category ID: 278
# 2351    3
# 3802    3
# 4497    5
# Name: age_range, dtype: int64
#
# Category ID: 302
# 76      5
# 274     6
# 461     6
# 715     3
# 1300    0
# 1552    6
# 1662    5
# Name: age_range, dtype: int64
#
# Category ID: 308
# 22      0
# 23      0
# 24      0
# 107     0
# 108     0
# 109     0
# 110     0
# 111     0
# 1030    4
# 1206    3
# 1213    5
# 2068    0
# 2069    0
# 2070    0
# 2420    4
# 2996    0
# 3529    0
# 3908    0
# 4430    0
# 4603    4
# 4604    4
# 4605    4
# 4606    4
# Name: age_range, dtype: int64
#
# Category ID: 351
# 176     6
# 4316    0
# Name: age_range, dtype: int64
#
# Category ID: 384
# 832     4
# 1102    4
# 2020    3
# 2021    3
# 2929    0
# 4427    2
# 4626    6
# Name: age_range, dtype: int64
#
# Category ID: 387
# 1628    3
# 1629    3
# Name: age_range, dtype: int64
#
# Category ID: 389
# 170     0
# 297     3
# 520     0
# 2431    3
# 3018    0
# 3020    3
# 3021    3
# 3103    0
# 3848    0
# Name: age_range, dtype: int64
#
# Category ID: 407
# 88      3
# 117     0
# 157     3
# 178     0
# 179     0
#        ..
# 4468    0
# 4469    0
# 4470    0
# 4487    0
# 4503    4
# Name: age_range, Length: 104, dtype: int64
#
# Category ID: 420
# 116    5
# Name: age_range, dtype: int64
#
# Category ID: 464
# 625    4
# 683    0
# Name: age_range, dtype: int64
#
# Category ID: 500
# 124     5
# 2329    6
# 2506    4
# 2507    4
# 3031    5
# 3461    0
# 3465    3
# 3466    3
# Name: age_range, dtype: int64
#
# Category ID: 555
# 375     6
# 1298    3
# 3844    2
# 3983    0
# Name: age_range, dtype: int64
#
# Category ID: 563
# 171     0
# 299     3
# 311     6
# 312     6
# 313     6
# 314     6
# 447     3
# 448     3
# 684     4
# 916     3
# 1176    2
# 1191    3
# 1485    3
# 1565    3
# 1566    3
# 1567    3
# 1568    3
# 1894    2
# 1997    3
# 2254    2
# 2255    2
# 2361    2
# 2677    2
# 2738    0
# 2811    4
# 2965    3
# 2966    3
# 2967    3
# 2968    3
# 3083    2
# 3456    5
# 3782    3
# 3797    3
# 3887    3
# 3888    3
# 4067    0
# 4158    3
# 4291    0
# 4292    0
# 4293    0
# 4496    6
# 4564    4
# 4624    5
# Name: age_range, dtype: int64
#
# Category ID: 602
# 2116    3
# Name: age_range, dtype: int64
#
# Category ID: 614
# 2563    2
# Name: age_range, dtype: int64
#
# Category ID: 639
# 135     0
# 450     4
# 1458    2
# 2687    3
# Name: age_range, dtype: int64
#
# Category ID: 641
# 2215    5
# 4019    4
# Name: age_range, dtype: int64
#
# Category ID: 656
# 0       5
# 40      4
# 122     2
# 172     2
# 227     0
#        ..
# 4392    2
# 4395    3
# 4482    0
# 4590    0
# 4591    0
# Name: age_range, Length: 142, dtype: int64
#
# Category ID: 662
# 1       3
# 46      6
# 58      0
# 60      0
# 61      6
#        ..
# 4588    4
# 4600    8
# 4601    8
# 4602    8
# 4618    0
# Name: age_range, Length: 334, dtype: int64
#
# Category ID: 737
# 119     3
# 128     3
# 168     5
# 169     5
# 219     0
#        ..
# 4584    2
# 4585    2
# 4586    2
# 4587    6
# 4630    0
# Name: age_range, Length: 111, dtype: int64
#
# Category ID: 748
# 647    2
# Name: age_range, dtype: int64
#
# Category ID: 756
# 1162    4
# 2324    5
# 2325    5
# 2326    5
# 2327    5
# 4144    6
# 4563    5
# Name: age_range, dtype: int64
#
# Category ID: 766
# 1125    4
# 1245    2
# 1623    0
# 2399    3
# 2400    3
# 2434    3
# 2571    4
# 3843    4
# Name: age_range, dtype: int64
#
# Category ID: 795
# 2328    5
# Name: age_range, dtype: int64
#
# Category ID: 812
# 1000    2
# 1001    2
# 1002    2
# 1003    2
# 1004    2
# 1005    2
# 1038    4
# 1063    5
# 1395    5
# 1459    0
# 1713    6
# 1734    0
# 2138    5
# 3359    0
# 3590    4
# 3591    4
# 3592    4
# 3593    4
# 3594    4
# 4609    0
# Name: age_range, dtype: int64
#
# Category ID: 815
# 1646    4
# Name: age_range, dtype: int64
#
# Category ID: 825
# 4521    0
# Name: age_range, dtype: int64
#
# Category ID: 833
# 199     4
# 200     4
# 253     2
# 268     3
# 292     6
# 293     6
# 294     6
# 295     6
# 296     6
# 331     6
# 432     3
# 526     6
# 527     6
# 528     6
# 911     4
# 971     5
# 1622    0
# 1697    0
# 1764    5
# 1765    5
# 2063    0
# 2383    0
# 2653    4
# 3101    0
# 3193    6
# 3194    6
# 3196    0
# 3197    0
# 3198    0
# 3212    6
# 3241    4
# 3324    2
# 3799    5
# 4164    6
# 4310    3
# 4529    2
# 4611    2
# Name: age_range, dtype: int64
#
# Category ID: 834
# 2979    6
# 2980    6
# 3566    2
# 3567    2
# 4333    4
# Name: age_range, dtype: int64
#
# Category ID: 844
# 851    3
# Name: age_range, dtype: int64
#
# Category ID: 895
# 1895    3
# 3011    4
# Name: age_range, dtype: int64
#
# Category ID: 898
# 62      3
# 87      5
# 230     3
# 231     3
# 232     4
#        ..
# 4481    4
# 4493    4
# 4594    3
# 4610    5
# 4613    4
# Name: age_range, Length: 149, dtype: int64
#
# Category ID: 946
# 787     5
# 1357    6
# Name: age_range, dtype: int64
#
# Category ID: 1023
# 1409    5
# 1759    2
# 4244    6
# Name: age_range, dtype: int64
#
# Category ID: 1075
# 120     3
# 121     3
# 129     4
# 192     6
# 228     6
#        ..
# 4330    3
# 4331    3
# 4483    6
# 4547    0
# 4617    3
# Name: age_range, Length: 62, dtype: int64
#
# Category ID: 1095
# 588     3
# 1107    0
# 1557    3
# 1641    0
# 1644    4
# 1645    4
# 1863    5
# 2107    3
# 2134    0
# 2509    0
# 2932    4
# 3489    3
# 3631    3
# 3960    3
# 4361    3
# Name: age_range, dtype: int64
#
# Category ID: 1098
# 84      5
# 85      5
# 637     3
# 725     4
# 1237    7
# 1238    7
# 1384    5
# 2253    4
# 2300    4
# 2301    4
# 2685    6
# 2686    6
# 3301    3
# 3497    4
# 3547    6
# 3772    3
# 4024    3
# Name: age_range, dtype: int64
#
# Category ID: 1112
# 28      4
# 29      4
# 30      4
# 77      0
# 78      6
#        ..
# 4526    6
# 4527    6
# 4556    0
# 4608    5
# 4623    6
# Name: age_range, Length: 122, dtype: int64
#
# Category ID: 1124
# 2312    2
# 3032    3
# Name: age_range, dtype: int64
#
# Category ID: 1142
# 910     0
# 1383    0
# Name: age_range, dtype: int64
#
# Category ID: 1147
# 115     3
# 4089    5
# Name: age_range, dtype: int64
#
# Category ID: 1157
# 1065    3
# 1066    3
# 1067    3
# 3410    5
# 3546    5
# 4150    0
# 4235    4
# Name: age_range, dtype: int64
#
# Category ID: 1174
# 3845    5
# Name: age_range, dtype: int64
#
# Category ID: 1181
# 190     6
# 2810    3
# Name: age_range, dtype: int64
#
# Category ID: 1188
# 1302    6
# 1303    6
# 1314    0
# 1502    4
# 1503    4
# 1766    3
# 3089    3
# 3954    7
# 4360    0
# 4380    4
# 4394    2
# 4479    0
# 4480    0
# 4549    4
# Name: age_range, dtype: int64
#
# Category ID: 1213
# 42      5
# 47      3
# 48      3
# 55      8
# 56      4
#        ..
# 4621    3
# 4638    4
# 4639    4
# 4640    4
# 4642    6
# Name: age_range, Length: 1024, dtype: int64
#
# Category ID: 1228
# 741     6
# 840     4
# 841     4
# 842     4
# 843     4
# 844     4
# 845     4
# 846     4
# 847     4
# 848     4
# 849     4
# 850     4
# 1014    5
# 1084    0
# 1085    0
# 1086    0
# 1087    0
# 1088    0
# 1111    5
# 1112    5
# 4045    0
# Name: age_range, dtype: int64
#
# Category ID: 1238
# 286     3
# 298     4
# 326     6
# 499     3
# 780     6
#        ..
# 4411    2
# 4412    2
# 4413    2
# 4629    5
# 4641    3
# Name: age_range, Length: 75, dtype: int64
#
# Category ID: 1271
# 1972    0
# 4403    4
# 4404    4
# 4405    4
# 4589    6
# Name: age_range, dtype: int64
#
# Category ID: 1293
# 1361    2
# 1362    2
# 1363    2
# 2123    5
# 2704    3
# 2705    3
# 2706    3
# 2827    3
# Name: age_range, dtype: int64
#
# Category ID: 1326
# 1486    4
# 1487    4
# 1488    4
# Name: age_range, dtype: int64
#
# Category ID: 1389
# 21      4
# 45      3
# 49      0
# 75      3
# 80      3
#        ..
# 4625    2
# 4627    3
# 4628    3
# 4636    6
# 4637    2
# Name: age_range, Length: 224, dtype: int64
#
# Category ID: 1397
# 159     4
# 330     5
# 1232    6
# 1506    6
# 1784    4
# 1785    4
# 1786    4
# 1955    3
# 2100    4
# 2156    0
# 2680    3
# 2695    5
# 2820    5
# 3664    3
# 3814    3
# 3923    6
# 3961    4
# 4387    4
# 4485    5
# Name: age_range, dtype: int64
#
# Category ID: 1401
# 425    4
# Name: age_range, dtype: int64
#
# Category ID: 1431
# 889     3
# 3693    0
# Name: age_range, dtype: int64
#
# Category ID: 1438
# 207     3
# 723     0
# 2880    2
# 3150    6
# 3151    6
# 3152    6
# 3153    6
# 3154    6
# 3155    6
# 3156    6
# 3157    6
# 3158    6
# 3159    6
# 3160    6
# 3161    6
# 3162    6
# 3163    6
# 3164    6
# 3165    6
# 3166    6
# 3436    3
# 3467    0
# 3624    4
# 4046    3
# 4047    3
# 4048    3
# 4049    3
# 4050    3
# 4191    3
# 4294    3
# 4295    3
# 4513    3
# 4582    3
# 4583    3
# Name: age_range, dtype: int64
#
# Category ID: 1467
# 35      2
# 63      3
# 64      3
# 65      3
# 66      3
# 67      3
# 68      3
# 69      3
# 70      3
# 291     4
# 524     4
# 525     4
# 818     5
# 826     0
# 827     0
# 828     0
# 1018    4
# 1221    3
# 1253    3
# 1282    4
# 1778    6
# 1936    0
# 2262    3
# 2526    5
# 2606    3
# 2607    3
# 2818    0
# 2826    3
# 2953    4
# 3013    3
# 3014    3
# 3015    3
# 3141    5
# 3615    3
# 3616    3
# 3694    3
# 3783    3
# 3911    0
# 3962    0
# 4436    0
# 4437    0
# 4438    0
# 4439    0
# 4440    0
# 4441    0
# 4442    0
# 4486    3
# 4614    3
# 4615    3
# 4616    3
# Name: age_range, dtype: int64
#
# Category ID: 1486
# 1016    5
# 1563    3
# Name: age_range, dtype: int64
#
# Category ID: 1505
# 220     5
# 259     6
# 460     6
# 928     6
# 934     4
# 1091    3
# 1189    4
# 1252    4
# 1277    3
# 1392    6
# 1393    6
# 1587    2
# 1611    4
# 1888    3
# 1889    3
# 2033    5
# 2073    6
# 2218    0
# 2219    0
# 2487    5
# 2769    4
# 2897    5
# 3496    2
# 3581    5
# 3702    4
# 3764    6
# 3913    3
# 4165    4
# 4379    6
# Name: age_range, dtype: int64
#
# Category ID: 1518
# 3586    3
# 3883    4
# Name: age_range, dtype: int64
#
# Category ID: 1528
# 102     0
# 1126    4
# 2917    4
# 4417    4
# Name: age_range, dtype: int64
#
# Category ID: 1553
# 646     0
# 762     3
# 763     3
# 833     6
# 857     0
# 1148    0
# 1149    0
# 1150    0
# 1151    0
# 1152    0
# 1270    4
# 1271    4
# 1272    4
# 1273    4
# 1274    4
# 2172    4
# 2580    0
# 2676    4
# 3715    4
# 3849    0
# 3850    0
# 3851    0
# 3852    0
# 3892    2
# 4172    0
# Name: age_range, dtype: int64
#
# Category ID: 1577
# 778     7
# 3294    5
# 4268    6
# 4269    6
# 4270    6
# 4271    6
# 4272    6
# 4273    6
# Name: age_range, dtype: int64
#
# Category ID: 1591
# 72      3
# 73      3
# 74      3
# 758     6
# 2502    5
# 3532    0
# 3533    0
# 3828    5
# 4302    4
# 4303    6
# Name: age_range, dtype: int64
#
# Category ID: 1656
# 451     4
# 4007    0
# 4008    0
# Name: age_range, dtype: int64
#
# Category ID: 1657
# 1472    3
# 1473    3
# 1907    5
# 2178    3
# 4004    4
# Name: age_range, dtype: int64

# %% [markdown]
# ### Top 5 categories in which females spent the most :

# %%
category_count = {}
for category_id, group in grouped_female_customers:
    category_count[category_id] = len(group)

sorted_categories = sorted(category_count.items(), key=lambda x: x[1], reverse=True)
sorted_categories

for i in range(5):
    category_id = sorted_categories[i][0]
    count = sorted_categories[i][1]
    print("Category ID:", category_id)
    print("Number of female customers:", count)
    print()
# Out:
# Category ID: 1213
# Number of female customers: 1024
#
# Category ID: 662
# Number of female customers: 334
#
# Category ID: 1389
# Number of female customers: 224
#
# Category ID: 898
# Number of female customers: 149
#
# Category ID: 656
# Number of female customers: 142

# %% [markdown]
# ### Top 5 categories in which males spent the most :

# %%
male_df = df[df['gender'] == 1]

grouped_male_customers = male_df.groupby('category_id')

category_count = {}
for category_id, group in grouped_male_customers:
    category_count[category_id] = len(group)

sorted_categories = sorted(category_count.items(), key=lambda x: x[1], reverse=True)
sorted_categories

for i in range(5):
    category_id = sorted_categories[i][0]
    count = sorted_categories[i][1]
    print("Category ID:", category_id)
    print("Number of male customers:", count)
    print()
# Out:
# Category ID: 1213
# Number of male customers: 783
#
# Category ID: 407
# Number of male customers: 82
#
# Category ID: 898
# Number of male customers: 62
#
# Category ID: 1075
# Number of male customers: 61
#
# Category ID: 1098
# Number of male customers: 59

# %% [markdown]
# ### How many men and women aren't regular purchasers of a merchant's product ?!

# %% [markdown]
# Label '0' = 176 rows (user is not a repeated buyer for the merchant)

# %% [markdown]
# Label '1' = 23 rows (user is a repeated buyer for the merchant)

# %% [markdown]
# Label '-1' = 4445 rows (user is not a new customer for the merchant)

# %%
non_repeated_buyers = df[df['label'] == 0]
non_repeated_buyers

# male_df = df[df['label'] == 0]

# gender_labels = {0: 'Female', 1: 'Male', 2: 'Unknown'}
# df['gender_label'] = df['gender'].replace(gender_labels)

sns.countplot(x='gender_label', data=non_repeated_buyers)
# Out:
# <AxesSubplot:xlabel='gender_label', ylabel='count'>

# %% [markdown]
# ### What do these males and female don't buy regularly ?

# %%
female_non_common_buyers_df = df[(df['gender'] == 0) & (df['label'] == 0)]
female_non_common_buyers_df

sns.countplot(x='category_id', data=female_non_common_buyers_df)
# Out:
# <AxesSubplot:xlabel='category_id', ylabel='count'>

# %% [markdown]
# Female dont buy the items in category ID 1389 on a regular basis

# %%
male_non_common_buyers_df = df[(df['gender'] == 1) & (df['label'] == 0)]
male_non_common_buyers_df

sns.countplot(x='category_id', data=male_non_common_buyers_df)
# Out:
# <AxesSubplot:xlabel='category_id', ylabel='count'>

# %% [markdown]
# Male dont buy the items under category ID 1098 on a regular basis. The items under category ID '1389' tops the next.

# %% [markdown]
# After comparing the trends, it appears that the products belonging to category ID 1096 have achieved the 5th highest position on the list for women and the 1st highest position on the list for men in a category where the act of purchasing the product from a merchant is relatively low.

# %% [markdown]
# If you want to convert a new customer who only buys products occasionally due to promotions and discounts into someone who buys products frequently from the merchant, you should concentrate on the merchants and the products they sell under categories with ID 1098 and 1389, rather than any other category item.
