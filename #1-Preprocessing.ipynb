# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('train_format2.csv')

# %%
df.head()
# Out:
#    user_id  age_range  gender  merchant_id  label  \
# 0    34176        6.0     0.0          944     -1
# 1    34176        6.0     0.0          412     -1
# 2    34176        6.0     0.0         1945     -1
# 3    34176        6.0     0.0         4752     -1
# 4    34176        6.0     0.0          643     -1
#
#                                         activity_log
# 0                            408895:1505:7370:1107:0
# 1  17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# 2  231901:662:2758:0818:0#231901:662:2758:0818:0#...
# 3                             174142:821:6938:1027:0
# 4                             716371:1505:968:1024:3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7030723 entries, 0 to 7030722
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   user_id       int64
#  1   age_range     float64
#  2   gender        float64
#  3   merchant_id   int64
#  4   label         int64
#  5   activity_log  object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 321.8+ MB

# %%
df['age_range'].isnull().sum()
# Out:
# 19380

# %%
df[df['age_range'].isna()]
# Out:
#          user_id  age_range  gender  merchant_id  label  \
# 8269      226176        NaN     NaN         1992     -1
# 8270      226176        NaN     NaN          487     -1
# 8271      226176        NaN     NaN         3910     -1
# 8272      226176        NaN     NaN          333     -1
# 8273      226176        NaN     NaN         1383     -1
# ...          ...        ...     ...          ...    ...
# 7024507   119423        NaN     NaN         4594     -1
# 7024508   119423        NaN     NaN         4559     -1
# 7024509   119423        NaN     NaN          184     -1
# 7024510   119423        NaN     NaN         2448     -1
# 7024511   119423        NaN     NaN          682     -1
#
#                                               activity_log
# 8269                               547751:1349:7279:0902:0
# 8270     817592:1349:7532:0624:0#894236:36:7532:0624:0#...
# 8271                               465321:1505:5484:0913:0
# ...

# %%
df['age_range'].fillna(0, inplace=True)

# %%
df['age_range'].isnull().sum()
# Out:
# 0

# %%
df['gender'].isnull().sum()
# Out:
# 61712

# %%
df['gender'].fillna(2, inplace=True)

# %%
df['gender'].isnull().sum()
# Out:
# 0

# %%
df.isnull().values.any()
# Out:
# True

# %%
df['user_id'].isnull().sum()
# Out:
# 0

# %%
df['merchant_id'].isnull().sum()
# Out:
# 0

# %%
df['activity_log'].isnull().sum()
# Out:
# 2975

# %%
df[df['activity_log'].isna()]
# Out:
#          user_id  age_range  gender  merchant_id  label activity_log
# 2521      182400        2.0     0.0         1519     -1          NaN
# 3623      190848        2.0     0.0          452     -1          NaN
# 9200      363393        3.0     0.0         4472     -1          NaN
# 9204      363393        3.0     0.0         3751     -1          NaN
# 9213      363393        3.0     0.0         3760     -1          NaN
# ...          ...        ...     ...          ...    ...          ...
# 7029034   413567        0.0     1.0         1539     -1          NaN
# 7029036   413567        0.0     1.0         1272     -1          NaN
# 7029041   413567        0.0     1.0         4545     -1          NaN
# 7029042   413567        0.0     1.0         4566     -1          NaN
# 7029044   413567        0.0     1.0         1138     -1          NaN
#
# [2975 rows x 6 columns]

# %%
len(df)
# Out:
# 7030723

# %%
df.dropna(inplace=True)

# %%
len(df)
# Out:
# 7027748

# %%
df['age_range'] = df['age_range'].astype(np.int64)

# %%
df['gender']=df['gender'].astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7027748 entries, 0 to 7030722
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   user_id       int64
#  1   age_range     int64
#  2   gender        int64
#  3   merchant_id   int64
#  4   label         int64
#  5   activity_log  object
# dtypes: int64(5), object(1)
# memory usage: 375.3+ MB

# %%
df.head()
# Out:
#    user_id  age_range  gender  merchant_id  label  \
# 0    34176          6       0          944     -1
# 1    34176          6       0          412     -1
# 2    34176          6       0         1945     -1
# 3    34176          6       0         4752     -1
# 4    34176          6       0          643     -1
#
#                                         activity_log
# 0                            408895:1505:7370:1107:0
# 1  17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# 2  231901:662:2758:0818:0#231901:662:2758:0818:0#...
# 3                             174142:821:6938:1027:0
# 4                             716371:1505:968:1024:3

# %%
len(df)
# Out:
# 7027748

# %%
df.iloc[2515:2525]
# Out:
#       user_id  age_range  gender  merchant_id  label  \
# 2515   247680          0       0         3835     -1
# 2516   247680          0       0         1659     -1
# 2517   182400          2       0         2347     -1
# 2518   182400          2       0         3139     -1
# 2519   182400          2       0         3643     -1
# 2520   182400          2       0          567     -1
# 2522   182400          2       0         1817     -1
# 2523   182400          2       0         3938      1
# 2524   182400          2       0         2685     -1
# 2525   182400          2       0         1917     -1
#
#                                            activity_log
# 2515  771985:1130:6086:1111:0#427268:1130:6086:1111:...
# 2516  542358:1130:7706:1111:0#542358:1130:7706:1111:...
# 2517  815416:1525:2246:0815:0#815416:1525:2246:0815:...
# 2518        441588:559:549:1111:0#441588:559:549:1111:2
# 2519                             206365:1211:163:0920:0
# ...

# %%
df.index.max()
# Out:
# 7030722

# %%
df = df.reset_index()

# %%
df.drop('index', axis=1, inplace=True)

# %%
df
# Out:
#          user_id  age_range  gender  merchant_id  label  \
# 0          34176          6       0          944     -1
# 1          34176          6       0          412     -1
# 2          34176          6       0         1945     -1
# 3          34176          6       0         4752     -1
# 4          34176          6       0          643     -1
# ...          ...        ...     ...          ...    ...
# 7027743   229247          4       2         2000     -1
# 7027744   229247          4       2          579     -1
# 7027745   229247          4       2         1860     -1
# 7027746   229247          4       2         4140      0
# 7027747   229247          4       2         3828     -1
#
#                                               activity_log
# 0                                  408895:1505:7370:1107:0
# 1        17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# 2        231901:662:2758:0818:0#231901:662:2758:0818:0#...
# ...

# %%
len(df)
# Out:
# 7027748

# %%
df = df.assign(a=df['activity_log'].str.split('#'))
df = df.explode('a')

# %%
df
# Out:
#          user_id  age_range  gender  merchant_id  label  \
# 0          34176          6       0          944     -1
# 1          34176          6       0          412     -1
# 1          34176          6       0          412     -1
# 1          34176          6       0          412     -1
# 1          34176          6       0          412     -1
# ...          ...        ...     ...          ...    ...
# 7027746   229247          4       2         4140      0
# 7027747   229247          4       2         3828     -1
# 7027747   229247          4       2         3828     -1
# 7027747   229247          4       2         3828     -1
# 7027747   229247          4       2         3828     -1
#
#                                               activity_log  \
# 0                                  408895:1505:7370:1107:0
# 1        17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# 1        17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# ...

# %%
df = df.reset_index()

# %%
df.drop('index', axis=1, inplace=True)

# %%
df
# Out:
#           user_id  age_range  gender  merchant_id  label  \
# 0           34176          6       0          944     -1
# 1           34176          6       0          412     -1
# 2           34176          6       0          412     -1
# 3           34176          6       0          412     -1
# 4           34176          6       0          412     -1
# ...           ...        ...     ...          ...    ...
# 27384134   229247          4       2         4140      0
# 27384135   229247          4       2         3828     -1
# 27384136   229247          4       2         3828     -1
# 27384137   229247          4       2         3828     -1
# 27384138   229247          4       2         3828     -1
#
#                                                activity_log  \
# 0                                   408895:1505:7370:1107:0
# 1         17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# 2         17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# ...

# %%
tdf=df.loc[0:2]

# %%
tdf
# Out:
#    user_id  age_range  gender  merchant_id  label  \
# 0    34176          6       0          944     -1
# 1    34176          6       0          412     -1
# 2    34176          6       0          412     -1
#
#                                         activity_log                        a
# 0                            408895:1505:7370:1107:0  408895:1505:7370:1107:0
# 1  17235:1604:4396:0818:0#954723:1604:4396:0818:0...   17235:1604:4396:0818:0
# 2  17235:1604:4396:0818:0#954723:1604:4396:0818:0...  954723:1604:4396:0818:0

# %%
df.loc[:, 't'] = df['a'].apply(lambda x: x.split(':'))

# %%
df
# Out:
#           user_id  age_range  gender  merchant_id  label  \
# 0           34176          6       0          944     -1
# 1           34176          6       0          412     -1
# 2           34176          6       0          412     -1
# 3           34176          6       0          412     -1
# 4           34176          6       0          412     -1
# ...           ...        ...     ...          ...    ...
# 27384134   229247          4       2         4140      0
# 27384135   229247          4       2         3828     -1
# 27384136   229247          4       2         3828     -1
# 27384137   229247          4       2         3828     -1
# 27384138   229247          4       2         3828     -1
#
#                                                activity_log  \
# 0                                   408895:1505:7370:1107:0
# 1         17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# 2         17235:1604:4396:0818:0#954723:1604:4396:0818:0...
# ...

# %%
df['item_id']=df['t'].apply(lambda x:x[0])

# %%
df.head()
# Out:
#    user_id  age_range  gender  merchant_id  label  \
# 0    34176          6       0          944     -1
# 1    34176          6       0          412     -1
# 2    34176          6       0          412     -1
# 3    34176          6       0          412     -1
# 4    34176          6       0          412     -1
#
#                                         activity_log                        a  \
# 0                            408895:1505:7370:1107:0  408895:1505:7370:1107:0
# 1  17235:1604:4396:0818:0#954723:1604:4396:0818:0...   17235:1604:4396:0818:0
# 2  17235:1604:4396:0818:0#954723:1604:4396:0818:0...  954723:1604:4396:0818:0
# 3  17235:1604:4396:0818:0#954723:1604:4396:0818:0...  275437:1604:4396:0818:0
# 4  17235:1604:4396:0818:0#954723:1604:4396:0818:0...  548906:1577:4396:1031:0
#
#                                t item_id
# 0  [408895, 1505, 7370, 1107, 0]  408895
# 1   [17235, 1604, 4396, 0818, 0]   17235
# 2  [954723, 1604, 4396, 0818, 0]  954723
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27384139 entries, 0 to 27384138
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   user_id       int64
#  1   age_range     int64
#  2   gender        int64
#  3   merchant_id   int64
#  4   label         int64
#  5   activity_log  object
#  6   a             object
#  7   t             object
#  8   item_id       object
# dtypes: int64(5), object(4)
# memory usage: 1.8+ GB

# %%
df['item_id']=df['item_id'].astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27384139 entries, 0 to 27384138
# Data columns (total 9 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   user_id       int64
#  1   age_range     int64
#  2   gender        int64
#  3   merchant_id   int64
#  4   label         int64
#  5   activity_log  object
#  6   a             object
#  7   t             object
#  8   item_id       int64
# dtypes: int64(6), object(3)
# memory usage: 1.8+ GB

# %%
#801 - 960
new_df=df[(df['item_id']>=801) & (df['item_id']<=960)]

# %%
new_df.head()
# Out:
#        user_id  age_range  gender  merchant_id  label  \
# 598      34944          5       0         2116     -1
# 10455   252288          3       0         3990     -1
# 21417   210048          3       1         4255     -1
# 21421   210048          3       1         4255     -1
# 21422   210048          3       1         4255     -1
#
#                                             activity_log  \
# 598    867411:656:7334:1021:0#867411:656:7334:1017:0#...
# 10455                                825:662:5644:0819:0
# 21417  866:1213:1573:0711:2#343454:267:1573:0711:2#79...
# 21421  866:1213:1573:0711:2#343454:267:1573:0711:2#79...
# 21422  866:1213:1573:0711:2#343454:267:1573:0711:2#79...
#
#                           a                           t  item_id
# 598     867:656:7334:1017:0   [867, 656, 7334, 1017, 0]      867
# 10455   825:662:5644:0819:0   [825, 662, 5644, 0819, 0]      825
# 21417  866:1213:1573:0711:2  [866, 1213, 1573, 0711, 2]      866
# ...

# %%
new_df['category_id']=new_df['t'].apply(lambda x:x[1])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\223717333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['category_id']=new_df['t'].apply(lambda x:x[1])

# %%
new_df['brand_id']=new_df['t'].apply(lambda x:x[2])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\426115228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['brand_id']=new_df['t'].apply(lambda x:x[2])

# %%
new_df['time_stamp']=new_df['t'].apply(lambda x:x[3])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\3527397114.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['time_stamp']=new_df['t'].apply(lambda x:x[3])

# %%
new_df['action_type']=new_df['t'].apply(lambda x:x[4])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\239541022.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['action_type']=new_df['t'].apply(lambda x:x[4])

# %%
new_df
# Out:
#           user_id  age_range  gender  merchant_id  label  \
# 598         34944          5       0         2116     -1
# 10455      252288          3       0         3990     -1
# 21417      210048          3       1         4255     -1
# 21421      210048          3       1         4255     -1
# 21422      210048          3       1         4255     -1
# ...           ...        ...     ...          ...    ...
# 27346150   230015          4       0         4255     -1
# 27346152   230015          4       0         4255     -1
# 27367647    64895          3       0         3491     -1
# 27370519     5759          6       0         4255     -1
# 27382574    96383          4       1         3462     -1
#
#                                                activity_log  \
# 598       867411:656:7334:1021:0#867411:656:7334:1017:0#...
# 10455                                   825:662:5644:0819:0
# 21417     866:1213:1573:0711:2#343454:267:1573:0711:2#79...
# ...

# %%
new_df.drop('activity_log',axis=1,inplace=True)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\3112622448.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop('activity_log',axis=1,inplace=True)

# %%
new_df.drop('a',axis=1,inplace=True)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\2809343225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop('a',axis=1,inplace=True)

# %%
new_df.drop('t',axis=1,inplace=True)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\551257538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop('t',axis=1,inplace=True)

# %%
new_df
# Out:
#           user_id  age_range  gender  merchant_id  label  item_id category_id  \
# 598         34944          5       0         2116     -1      867         656
# 10455      252288          3       0         3990     -1      825         662
# 21417      210048          3       1         4255     -1      866        1213
# 21421      210048          3       1         4255     -1      866        1213
# 21422      210048          3       1         4255     -1      866        1213
# ...           ...        ...     ...          ...    ...      ...         ...
# 27346150   230015          4       0         4255     -1      866        1213
# 27346152   230015          4       0         4255     -1      866        1213
# 27367647    64895          3       0         3491     -1      860        1238
# 27370519     5759          6       0         4255     -1      866        1213
# 27382574    96383          4       1         3462     -1      916         563
#
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4644 entries, 598 to 27382574
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      4644 non-null   int64
#  1   age_range    4644 non-null   int64
#  2   gender       4644 non-null   int64
#  3   merchant_id  4644 non-null   int64
#  4   label        4644 non-null   int64
#  5   item_id      4644 non-null   int64
#  6   category_id  4644 non-null   object
#  7   brand_id     4644 non-null   object
#  8   time_stamp   4644 non-null   object
#  9   action_type  4644 non-null   object
# dtypes: int64(6), object(4)
# memory usage: 528.1+ KB

# %%
new_df['category_id']=new_df['category_id'].astype(np.int64)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\191893653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['category_id']=new_df['category_id'].astype(np.int64)

# %%
new_df['brand_id']=new_df['brand_id'].astype(np.int64)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\3777877572.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['brand_id']=new_df['brand_id'].astype(np.int64)

# %%
new_df['time_stamp']=new_df['time_stamp'].astype(np.int64)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\277199408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['time_stamp']=new_df['time_stamp'].astype(np.int64)

# %%
new_df['action_type']=new_df['action_type'].astype(np.int64)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_26144\3725367966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['action_type']=new_df['action_type'].astype(np.int64)

# %%
new_df
# Out:
#           user_id  age_range  gender  merchant_id  label  item_id  \
# 598         34944          5       0         2116     -1      867
# 10455      252288          3       0         3990     -1      825
# 21417      210048          3       1         4255     -1      866
# 21421      210048          3       1         4255     -1      866
# 21422      210048          3       1         4255     -1      866
# ...           ...        ...     ...          ...    ...      ...
# 27346150   230015          4       0         4255     -1      866
# 27346152   230015          4       0         4255     -1      866
# 27367647    64895          3       0         3491     -1      860
# 27370519     5759          6       0         4255     -1      866
# 27382574    96383          4       1         3462     -1      916
#
#           category_id  brand_id  time_stamp  action_type
# 598               656      7334        1017            0
# 10455             662      5644         819            0
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4644 entries, 598 to 27382574
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      4644 non-null   int64
#  1   age_range    4644 non-null   int64
#  2   gender       4644 non-null   int64
#  3   merchant_id  4644 non-null   int64
#  4   label        4644 non-null   int64
#  5   item_id      4644 non-null   int64
#  6   category_id  4644 non-null   int64
#  7   brand_id     4644 non-null   int64
#  8   time_stamp   4644 non-null   int64
#  9   action_type  4644 non-null   int64
# dtypes: int64(10)
# memory usage: 528.1 KB

# %%
new_df = new_df.reset_index()

# %%
new_df.head()
# Out:
#    index  user_id  age_range  gender  merchant_id  label  item_id  \
# 0    598    34944          5       0         2116     -1      867
# 1  10455   252288          3       0         3990     -1      825
# 2  21417   210048          3       1         4255     -1      866
# 3  21421   210048          3       1         4255     -1      866
# 4  21422   210048          3       1         4255     -1      866
#
#    category_id  brand_id  time_stamp  action_type
# 0          656      7334        1017            0
# 1          662      5644         819            0
# 2         1213      1573         711            2
# 3         1213      1573         711            0
# 4         1213      1573         711            0

# %%
new_df.drop('index', axis=1, inplace=True)

# %%
new_df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      252288          3       0         3990     -1      825          662
# 2      210048          3       1         4255     -1      866         1213
# 3      210048          3       1         4255     -1      866         1213
# 4      210048          3       1         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015          4       0         4255     -1      866         1213
# 4640   230015          4       0         4255     -1      866         1213
# 4641    64895          3       0         3491     -1      860         1238
# 4642     5759          6       0         4255     -1      866         1213
# 4643    96383          4       1         3462     -1      916          563
#
#       brand_id  time_stamp  action_type
# ...

# %%
new_df.to_csv('processed_data.csv', index=False)
