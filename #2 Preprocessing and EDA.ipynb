# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from datetime import datetime, timedelta

# %%
df= pd.read_csv('processed_data.csv')

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      252288          3       0         3990     -1      825          662
# 2      210048          3       1         4255     -1      866         1213
# 3      210048          3       1         4255     -1      866         1213
# 4      210048          3       1         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015          4       0         4255     -1      866         1213
# 4640   230015          4       0         4255     -1      866         1213
# 4641    64895          3       0         3491     -1      860         1238
# 4642     5759          6       0         4255     -1      866         1213
# 4643    96383          4       1         3462     -1      916          563
#
#       brand_id  time_stamp  action_type
# ...

# %%
df['merchant_id'].nunique()
# Out:
# 132

# %%
sns.countplot(x='age_range',hue='gender', data=df, palette='Set2')
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='count'>

# %%
df[df['gender']==0]['age_range'].mean()
#replace men age as 3
# Out:
# 3.363542739443872

# %%
df[df['gender']==1]['age_range'].mean()
#replcae female age as 3 as well
# Out:
# 3.4026152787336543

# %%
print('Shape of the dataframe:', df.shape)
# Out:
# Shape of the dataframe: (4644, 10)

# %%
sns.histplot(df['age_range'])
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='Count'>

# %%
sns.boxplot(x='gender', y='age_range', data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age_range'>

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='gender', data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.scatterplot(x='age_range', y='merchant_id', data=df)
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='merchant_id'>

# %%
sns.boxplot(x='gender', y='merchant_id', data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='merchant_id'>

# %%
sns.pairplot(df)

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      252288          3       0         3990     -1      825          662
# 2      210048          3       1         4255     -1      866         1213
# 3      210048          3       1         4255     -1      866         1213
# 4      210048          3       1         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015          4       0         4255     -1      866         1213
# 4640   230015          4       0         4255     -1      866         1213
# 4641    64895          3       0         3491     -1      860         1238
# 4642     5759          6       0         4255     -1      866         1213
# 4643    96383          4       1         3462     -1      916          563
#
#       brand_id  time_stamp  action_type
# ...

# %%
sns.pairplot(df,hue='merchant_id')

# %%
pivot_table = df.pivot_table(index='age_range', columns='merchant_id', values='label', aggfunc='count')
sns.heatmap(pivot_table)
# Out:
# <AxesSubplot:xlabel='merchant_id', ylabel='age_range'>

# %%
sns.kdeplot(data=df, x='item_id')
# Out:
# <AxesSubplot:xlabel='item_id', ylabel='Density'>

# %%
sns.kdeplot(data=df, x='age_range', y='item_id', fill=True)
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='item_id'>

# %%
sns.kdeplot(data=df, x='age_range', y='category_id', fill=True)
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='category_id'>

# %%
sns.kdeplot(data=df, x='age_range', y='brand_id', fill=True)
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='brand_id'>

# %%
sns.kdeplot(data=df, x='age_range', y='merchant_id', fill=True)
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='merchant_id'>

# %%
sns.countplot(x='action_type', data=df)
# Out:
# <AxesSubplot:xlabel='action_type', ylabel='count'>

# %% [markdown]
# Handeling Null values for Gender and Age Range

# %%
df['age_range'] = df['age_range'].replace(0, pd.np.nan)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_24188\2183916099.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['age_range'] = df['age_range'].replace(0, pd.np.nan)

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
df['age_range'] = df['age_range'].fillna(3)

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944        5.0       0         2116     -1      867          656
# 1      252288        3.0       0         3990     -1      825          662
# 2      210048        3.0       1         4255     -1      866         1213
# 3      210048        3.0       1         4255     -1      866         1213
# 4      210048        3.0       1         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015        4.0       0         4255     -1      866         1213
# 4640   230015        4.0       0         4255     -1      866         1213
# 4641    64895        3.0       0         3491     -1      860         1238
# 4642     5759        6.0       0         4255     -1      866         1213
# 4643    96383        4.0       1         3462     -1      916          563
#
#       brand_id  time_stamp  action_type
# ...

# %%
sns.boxplot(x='gender', y='age_range', data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age_range'>

# %%
sns.histplot(data=df, x='age_range')
# Out:
# <AxesSubplot:xlabel='age_range', ylabel='Count'>

# %%
sns.countplot(x='gender', data=df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
df['gender'] = df['gender'].replace(2, pd.np.nan)
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_24188\789196261.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   df['gender'] = df['gender'].replace(2, pd.np.nan)

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Replace Gender values to 0, female

# %%
df['gender'] = df['gender'].fillna(0)

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944        5.0     0.0         2116     -1      867          656
# 1      252288        3.0     0.0         3990     -1      825          662
# 2      210048        3.0     1.0         4255     -1      866         1213
# 3      210048        3.0     1.0         4255     -1      866         1213
# 4      210048        3.0     1.0         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015        4.0     0.0         4255     -1      866         1213
# 4640   230015        4.0     0.0         4255     -1      866         1213
# 4641    64895        3.0     0.0         3491     -1      860         1238
# 4642     5759        6.0     0.0         4255     -1      866         1213
# 4643    96383        4.0     1.0         3462     -1      916          563
#
#       brand_id  time_stamp  action_type
# ...

# %%
df.dtypes
# Out:
# user_id          int64
# age_range      float64
# gender         float64
# merchant_id      int64
# label            int64
# item_id          int64
# category_id      int64
# brand_id         int64
# time_stamp       int64
# action_type      int64
# dtype: object

# %%
df['age_range'] = df['age_range'].astype(np.int64)

# %%
df['gender'] = df['gender'].astype(np.int64)

# %%
df.dtypes
# Out:
# user_id        int64
# age_range      int64
# gender         int64
# merchant_id    int64
# label          int64
# item_id        int64
# category_id    int64
# brand_id       int64
# time_stamp     int64
# action_type    int64
# dtype: object

# %%
df.to_csv('EDA_data.csv', index=False)
