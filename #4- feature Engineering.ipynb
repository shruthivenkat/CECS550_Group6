# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from datetime import datetime, timedelta

# %%
df= pd.read_csv('EDA_data.csv')

# %%
df.head()
# Out:
#    user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0    34944          5       0         2116     -1      867          656
# 1   252288          3       0         3990     -1      825          662
# 2   210048          3       1         4255     -1      866         1213
# 3   210048          3       1         4255     -1      866         1213
# 4   210048          3       1         4255     -1      866         1213
#
#    brand_id  time_stamp  action_type
# 0      7334        1017            0
# 1      5644         819            0
# 2      1573         711            2
# 3      1573         711            0
# 4      1573         711            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4644 entries, 0 to 4643
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      4644 non-null   int64
#  1   age_range    4644 non-null   int64
#  2   gender       4644 non-null   int64
#  3   merchant_id  4644 non-null   int64
#  4   label        4644 non-null   int64
#  5   item_id      4644 non-null   int64
#  6   category_id  4644 non-null   int64
#  7   brand_id     4644 non-null   int64
#  8   time_stamp   4644 non-null   int64
#  9   action_type  4644 non-null   int64
# dtypes: int64(10)
# memory usage: 362.9 KB

# %%
#duplicates = df[df.duplicated()]

# %%
#duplicates

# %%
#df= df.drop_duplicates()

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      252288          3       0         3990     -1      825          662
# 2      210048          3       1         4255     -1      866         1213
# 3      210048          3       1         4255     -1      866         1213
# 4      210048          3       1         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015          4       0         4255     -1      866         1213
# 4640   230015          4       0         4255     -1      866         1213
# 4641    64895          3       0         3491     -1      860         1238
# 4642     5759          6       0         4255     -1      866         1213
# 4643    96383          4       1         3462     -1      916          563
#
#       brand_id  time_stamp  action_type
# ...

# %%
df['time_stamp'] = pd.to_datetime(df['time_stamp'], format='%m%d')

# %%
df['month'] = df['time_stamp'].dt.month
df['day'] = df['time_stamp'].dt.day

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      252288          3       0         3990     -1      825          662
# 2      210048          3       1         4255     -1      866         1213
# 3      210048          3       1         4255     -1      866         1213
# 4      210048          3       1         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015          4       0         4255     -1      866         1213
# 4640   230015          4       0         4255     -1      866         1213
# 4641    64895          3       0         3491     -1      860         1238
# 4642     5759          6       0         4255     -1      866         1213
# 4643    96383          4       1         3462     -1      916          563
#
#       brand_id time_stamp  action_type  month  day
# ...

# %%
df[df['action_type']==1]
# Out:
# Empty DataFrame
# Columns: [user_id, age_range, gender, merchant_id, label, item_id, category_id, brand_id, time_stamp, action_type, month, day]
# Index: []

# %%
user_activity = df.groupby('user_id')['action_type'].value_counts().unstack(fill_value=0)

# %%
user_activity
# Out:
# action_type  0  2  3
# user_id
# 170          2  0  0
# 393          1  0  0
# 699          1  0  0
# 784          1  0  0
# 867          1  0  0
# ...         .. .. ..
# 422954       1  0  0
# 422967       2  0  0
# 423225       1  0  0
# 423387       1  0  0
# 424156       3  0  0
#
# [2447 rows x 3 columns]

# %%
user_activity.columns = ['clicks', 'purchases', 'add_to_fav']
#there is no one with action type = 1 i.e. ADD TO CART, so removed
user_activity = user_activity.reset_index()

# %%
user_activity['add_to_cart']=0

# %%
user_activity
# Out:
#       user_id  clicks  purchases  add_to_fav  add_to_cart
# 0         170       2          0           0            0
# 1         393       1          0           0            0
# 2         699       1          0           0            0
# 3         784       1          0           0            0
# 4         867       1          0           0            0
# ...       ...     ...        ...         ...          ...
# 2442   422954       1          0           0            0
# 2443   422967       2          0           0            0
# 2444   423225       1          0           0            0
# 2445   423387       1          0           0            0
# 2446   424156       3          0           0            0
#
# [2447 rows x 5 columns]

# %%
merchant_activity = df.groupby('merchant_id')['action_type'].value_counts().unstack(fill_value=0)

# %%
merchant_activity
# Out:
# action_type   0  2  3
# merchant_id
# 67            1  0  0
# 94            1  0  0
# 111           5  0  0
# 145           5  0  0
# 173          37  0  2
# ...          .. .. ..
# 4850         20  2  1
# 4883          1  0  0
# 4896          1  0  0
# 4921          8  0  0
# 4945         15  0  2
#
# [132 rows x 3 columns]

# %%
merchant_activity.columns = ['clicks', 'purchases', 'add_to_fav']
merchant_activity = merchant_activity.reset_index()

# %%
merchant_activity
# Out:
#      merchant_id  clicks  purchases  add_to_fav
# 0             67       1          0           0
# 1             94       1          0           0
# 2            111       5          0           0
# 3            145       5          0           0
# 4            173      37          0           2
# ..           ...     ...        ...         ...
# 127         4850      20          2           1
# 128         4883       1          0           0
# 129         4896       1          0           0
# 130         4921       8          0           0
# 131         4945      15          0           2
#
# [132 rows x 4 columns]

# %%
merchant_activity['add_to_cart']=0

# %%
user_activity
# Out:
#       user_id  clicks  purchases  add_to_fav  add_to_cart
# 0         170       2          0           0            0
# 1         393       1          0           0            0
# 2         699       1          0           0            0
# 3         784       1          0           0            0
# 4         867       1          0           0            0
# ...       ...     ...        ...         ...          ...
# 2442   422954       1          0           0            0
# 2443   422967       2          0           0            0
# 2444   423225       1          0           0            0
# 2445   423387       1          0           0            0
# 2446   424156       3          0           0            0
#
# [2447 rows x 5 columns]

# %%
merchant_activity
# Out:
#      merchant_id  clicks  purchases  add_to_fav  add_to_cart
# 0             67       1          0           0            0
# 1             94       1          0           0            0
# 2            111       5          0           0            0
# 3            145       5          0           0            0
# 4            173      37          0           2            0
# ..           ...     ...        ...         ...          ...
# 127         4850      20          2           1            0
# 128         4883       1          0           0            0
# 129         4896       1          0           0            0
# 130         4921       8          0           0            0
# 131         4945      15          0           2            0
#
# [132 rows x 5 columns]

# %%
df = pd.merge(df, user_activity, on='user_id')

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      252288          3       0         3990     -1      825          662
# 2      210048          3       1         4255     -1      866         1213
# 3      210048          3       1         4255     -1      866         1213
# 4      210048          3       1         4255     -1      866         1213
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639   230015          4       0         4255     -1      866         1213
# 4640   230015          4       0         4255     -1      866         1213
# 4641    64895          3       0         3491     -1      860         1238
# 4642     5759          6       0         4255     -1      866         1213
# 4643    96383          4       1         3462     -1      916          563
#
# ...

# %%
df = pd.merge(df, merchant_activity, on='merchant_id')

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      356994          4       0         2116     -1      867          656
# 2      226947          5       1         2116     -1      867          656
# 3      181140          2       0         2116     -1      867          656
# 4      296862          2       0         2116     -1      867          656
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639    64070          3       1         4883     -1      925          247
# 4640   122951          3       0         1600     -1      848          351
# 4641   400742          5       1         1509     -1      810         1213
# 4642    75113          3       0         2948     -1      899          825
# 4643   378491          3       0           94     -1      863          662
#
# ...

# %%
df = df.rename(columns={'clicks_x': 'No. of total clicks by user_id'})

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      356994          4       0         2116     -1      867          656
# 2      226947          5       1         2116     -1      867          656
# 3      181140          2       0         2116     -1      867          656
# 4      296862          2       0         2116     -1      867          656
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639    64070          3       1         4883     -1      925          247
# 4640   122951          3       0         1600     -1      848          351
# 4641   400742          5       1         1509     -1      810         1213
# 4642    75113          3       0         2948     -1      899          825
# 4643   378491          3       0           94     -1      863          662
#
#       brand_id time_stamp  action_type  month  day  \
# ...

# %%
df = df.rename(columns={'No. of total clicks by user_id': 'Total no. of clicks by user_id for all merchant_id'})

# %%
df = df.rename(columns={'purchases_x': 'Total no. of purchased by user_id for all merchant_id'})

# %%
df = df.rename(columns={'add_to_fav_x': 'Total no. of add_to_fav by user_id for all merchant_id'})

# %%
df = df.rename(columns={'add_to_cart_x': 'Total no. of add_to_cart by user_id for all merchant_id'})

# %%
df = df.rename(columns={'clicks_y': 'Total no. of clicks by all user_id for merchant_id'})

# %%
df = df.rename(columns={'purchases_y': 'Total no. of purchases by all user_id for merchant_id'})

# %%
df = df.rename(columns={'add_to_fav_y': 'Total no. of add_to_fav by all user_id for merchant_id'})

# %%
df = df.rename(columns={'add_to_cart_y': 'Total no. of add_to_cart by all user_id for merchant_id'})

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      356994          4       0         2116     -1      867          656
# 2      226947          5       1         2116     -1      867          656
# 3      181140          2       0         2116     -1      867          656
# 4      296862          2       0         2116     -1      867          656
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639    64070          3       1         4883     -1      925          247
# 4640   122951          3       0         1600     -1      848          351
# 4641   400742          5       1         1509     -1      810         1213
# 4642    75113          3       0         2948     -1      899          825
# 4643   378491          3       0           94     -1      863          662
#
#       brand_id time_stamp  action_type  month  day  \
# ...

# %% [markdown]
# All DF available
# merchant activity
# user activity
# df

# %%
merchant_activity
# Out:
#      merchant_id  clicks  purchases  add_to_fav  add_to_cart
# 0             67       1          0           0            0
# 1             94       1          0           0            0
# 2            111       5          0           0            0
# 3            145       5          0           0            0
# 4            173      37          0           2            0
# ..           ...     ...        ...         ...          ...
# 127         4850      20          2           1            0
# 128         4883       1          0           0            0
# 129         4896       1          0           0            0
# 130         4921       8          0           0            0
# 131         4945      15          0           2            0
#
# [132 rows x 5 columns]

# %%
user_activity
# Out:
#       user_id  clicks  purchases  add_to_fav  add_to_cart
# 0         170       2          0           0            0
# 1         393       1          0           0            0
# 2         699       1          0           0            0
# 3         784       1          0           0            0
# 4         867       1          0           0            0
# ...       ...     ...        ...         ...          ...
# 2442   422954       1          0           0            0
# 2443   422967       2          0           0            0
# 2444   423225       1          0           0            0
# 2445   423387       1          0           0            0
# 2446   424156       3          0           0            0
#
# [2447 rows x 5 columns]

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      356994          4       0         2116     -1      867          656
# 2      226947          5       1         2116     -1      867          656
# 3      181140          2       0         2116     -1      867          656
# 4      296862          2       0         2116     -1      867          656
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639    64070          3       1         4883     -1      925          247
# 4640   122951          3       0         1600     -1      848          351
# 4641   400742          5       1         1509     -1      810         1213
# 4642    75113          3       0         2948     -1      899          825
# 4643   378491          3       0           94     -1      863          662
#
#       brand_id time_stamp  action_type  month  day  \
# ...

# %%
def pur(x):
    if x==2:
        return 1
    else:
        return 0

# %%
df['purchased?']=df['action_type'].apply(pur)
#if purchased== 1, if not purchased 0

# %%
df
# Out:
#       user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 0       34944          5       0         2116     -1      867          656
# 1      356994          4       0         2116     -1      867          656
# 2      226947          5       1         2116     -1      867          656
# 3      181140          2       0         2116     -1      867          656
# 4      296862          2       0         2116     -1      867          656
# ...       ...        ...     ...          ...    ...      ...          ...
# 4639    64070          3       1         4883     -1      925          247
# 4640   122951          3       0         1600     -1      848          351
# 4641   400742          5       1         1509     -1      810         1213
# 4642    75113          3       0         2948     -1      899          825
# 4643   378491          3       0           94     -1      863          662
#
#       brand_id time_stamp  action_type  ...  day  \
# ...

# %%
duplicates = df[(df.duplicated()) & (df['action_type']==2)]

# %%
duplicates[duplicates['user_id']==36525]
# Out:
#      user_id  age_range  gender  merchant_id  label  item_id  category_id  \
# 460    36525          4       0         4255     -1      866         1213
#
#      brand_id time_stamp  action_type  ...  day  \
# 460      1573 1900-08-13            2  ...   13
#
#      Total no. of clicks by user_id for all merchant_id  \
# 460                                                  3
#
#      Total no. of purchased by user_id for all merchant_id  \
# 460                                                  2
#
#      Total no. of add_to_fav by user_id for all merchant_id  \
# 460                                                  0
#
#      Total no. of add_to_cart by user_id for all merchant_id  \
# 460                                                  0
#
#      Total no. of clicks by all user_id for merchant_id  \
# 460                                               1457
#
#      Total no. of purchases by all user_id for merchant_id  \
# 460                                                464
#
# ...
